# %%
#file location
file_location="/FileStore/tables/tips.csv"
file_type='csv'
#The applied options are for CSV files.FOr other file tyes,will be ignored.
df=spark.read.csv(file_location,header=True,inferSchema=True)
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----+------+------+---+------+----+
# total_bill| tip|   sex|smoker|day|  time|size|
# +----------+----+------+------+---+------+----+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|
#      21.01| 3.5|  Male|    No|Sun|Dinner|   3|
#      23.68|3.31|  Male|    No|Sun|Dinner|   2|
#      24.59|3.61|Female|    No|Sun|Dinner|   4|
#      25.29|4.71|  Male|    No|Sun|Dinner|   4|
#       8.77| 2.0|  Male|    No|Sun|Dinner|   2|
#      26.88|3.12|  Male|    No|Sun|Dinner|   4|
#      15.04|1.96|  Male|    No|Sun|Dinner|   2|
#      14.78|3.23|  Male|    No|Sun|Dinner|   2|
# ...

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- total_bill: double (nullable = true)
# -- tip: double (nullable = true)
# -- sex: string (nullable = true)
# -- smoker: string (nullable = true)
# -- day: string (nullable = true)
# -- time: string (nullable = true)
# -- size: integer (nullable = true)
#
# </div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [&#39;total_bill&#39;, &#39;tip&#39;, &#39;sex&#39;, &#39;smoker&#39;, &#39;day&#39;, &#39;time&#39;, &#39;size&#39;]</div>

# %%
#Handling categorical features. Dummy variables 1,0

from pyspark.ml.feature import StringIndexer
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
indexer=StringIndexer(inputCol='sex',outputCol='sex_indexed')
df_r=indexer.fit(df).transform(df)
df_r.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----+------+------+---+------+----+-----------+
# total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|
# +----------+----+------+------+---+------+----+-----------+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|
#      21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|
#      23.68|3.31|  Male|    No|Sun|Dinner|   2|        0.0|
#      24.59|3.61|Female|    No|Sun|Dinner|   4|        1.0|
#      25.29|4.71|  Male|    No|Sun|Dinner|   4|        0.0|
#       8.77| 2.0|  Male|    No|Sun|Dinner|   2|        0.0|
# ...

# %%
indexer=StringIndexer(inputCols=['sex','smoker','day','time'],outputCols=['sex_indexed','smoker_indexed','day_indexed','time_indexed'])
df_r=indexer.fit(df).transform(df)
df_r.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+
# total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|smoker_indexed|day_indexed|time_indexed|
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|           0.0|        1.0|         0.0|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|
#      21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|
# ...

# %%
#grouping independent variables and the independent variables in Output col.
from pyspark.ml.feature import VectorAssembler
featureassembler=VectorAssembler(inputCols=['tip','size','sex_indexed','smoker_indexed','day_indexed','time_indexed'],outputCol="Independent Features")
output=featureassembler.transform(df_r)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+--------------------+
# total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|smoker_indexed|day_indexed|time_indexed|Independent Features|
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+--------------------+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|           0.0|        1.0|         0.0|[1.01,2.0,1.0,0.0...|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|[1.66,3.0,0.0,0.0...|
# ...

# %%
output.select('Independent Features').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
# Independent Features|
# +--------------------+
# [1.01,2.0,1.0,0.0...|
# [1.66,3.0,0.0,0.0...|
# [3.5,3.0,0.0,0.0,...|
# [3.31,2.0,0.0,0.0...|
# [3.61,4.0,1.0,0.0...|
# [4.71,4.0,0.0,0.0...|
# [2.0,2.0,0.0,0.0,...|
# [3.12,4.0,0.0,0.0...|
# [1.96,2.0,0.0,0.0...|
# [3.23,2.0,0.0,0.0...|
# [1.71,2.0,0.0,0.0...|
# [5.0,4.0,1.0,0.0,...|
# [1.57,2.0,0.0,0.0...|
# [3.0,4.0,0.0,0.0,...|
# [3.02,2.0,1.0,0.0...|
# [3.92,2.0,0.0,0.0...|
# [1.67,3.0,1.0,0.0...|
# [3.71,3.0,0.0,0.0...|
# [3.5,3.0,1.0,0.0,...|
# (6,[0,1],[3.35,3.0])|
# +--------------------+
# only showing top 20 rows
#
# </div>

# %%
finalize_data=output.select("Independent Features","total_bill")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
finalize_data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----------+
# Independent Features|total_bill|
# +--------------------+----------+
# [1.01,2.0,1.0,0.0...|     16.99|
# [1.66,3.0,0.0,0.0...|     10.34|
# [3.5,3.0,0.0,0.0,...|     21.01|
# [3.31,2.0,0.0,0.0...|     23.68|
# [3.61,4.0,1.0,0.0...|     24.59|
# [4.71,4.0,0.0,0.0...|     25.29|
# [2.0,2.0,0.0,0.0,...|      8.77|
# [3.12,4.0,0.0,0.0...|     26.88|
# [1.96,2.0,0.0,0.0...|     15.04|
# [3.23,2.0,0.0,0.0...|     14.78|
# [1.71,2.0,0.0,0.0...|     10.27|
# [5.0,4.0,1.0,0.0,...|     35.26|
# [1.57,2.0,0.0,0.0...|     15.42|
# [3.0,4.0,0.0,0.0,...|     18.43|
# [3.02,2.0,1.0,0.0...|     14.83|
# ...

# %%
from pyspark.ml.regression import LinearRegression
#train test split
train_data,test_data=finalize_data.randomSplit([0.75,0.25])
regressor=LinearRegression(featuresCol="Independent Features",labelCol="total_bill")
regressor=regressor.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
regressor.coefficients
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: DenseVector([3.4633, 3.2472, -1.6194, 2.6866, -0.0098, -1.1308])</div>

# %%
regressor.intercept
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: 1.2469452094429836</div>

# %%
#Predictions
pred_results=regressor.evaluate(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#final comparison result vs prediction
pred_results.predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----------+------------------+
# Independent Features|total_bill|        prediction|
# +--------------------+----------+------------------+
# (6,[0,1],[1.25,2.0])|     10.51|12.070503112420564|
# (6,[0,1],[2.24,3.0])|     16.04|18.746385466404224|
# (6,[0,1],[2.34,4.0])|     17.81|22.339933496496286|
# (6,[0,1],[2.72,2.0])|     13.28|17.161549692331402|
# (6,[0,1],[3.27,2.0])|     17.78|19.066363038556542|
#  (6,[0,1],[3.6,3.0])|     24.06| 23.45646937707003|
# (6,[0,1],[4.08,2.0])|     17.92|21.871633602997207|
#  (6,[0,1],[9.0,4.0])|     48.33|45.405491470786195|
# ...

# %%
pred_results.r2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: 0.5563004778686531</div>

# %%
pred_results.meanAbsoluteError
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: 4.097177861402277</div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
